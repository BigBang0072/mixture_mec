# %%
import numpy as np
import matplotlib.pyplot as plt
from scm_module import *

# %%
def get_best_estimated_matching_error(intv_args_dict,gm):
    '''
    '''
    mean_list=gm.means_
    cov_list = gm.covariances_

    comp_perm_list = it.permutations(intv_args_dict.keys())
    min_err = float("inf")
    min_perm=None
    for comp_perm in comp_perm_list:
        err = 0.0
        for cidx,comp in enumerate(comp_perm):
            mean_err = np.sum(
                np.abs(mean_list[cidx]-intv_args_dict[comp]["true_params"]["mui"])
            )
            cov_error = np.sum(
                np.abs(cov_list[cidx]-intv_args_dict[comp]["true_params"]["Si"])
            )
            err+=mean_err+cov_error
        #Now checking if this perm/matching gives minimum error
        if err<min_err:
            min_err=err 
            min_perm=comp_perm
    print("error:",min_err)
    print("min_perm:",min_perm)
    return min_err,min_perm


def sample_expt_runner(gSCM,num_samples,num_nodes,new_noise_mean):
    #Genetaing the samples from each of the mixture
    intv_args_dict={}
    mixture_samples=[]
    for nidx in range(num_nodes):
        #Creating the interv args
        intv_args=dict(
                    intv_type="do",
                    inode=nidx,
                    new_mui=new_noise_mean, #need not keep it different
        )
        #Generating the samples for this internvetions
        X,true_params = gSCM.generate_sample_with_atomic_intervention(
                                        num_samples=num_samples,
                                        intv_args=intv_args
        )
        mixture_samples.append(X)
        #Upting the true param of this dist to compare later
        intv_args["true_params"]=true_params
        intv_args_dict[str(nidx)]=intv_args
    #Adding the observational distribution
    intv_args=dict(intv_type="obs")
    Xobs,obs_true_params = gSCM.generate_sample_with_atomic_intervention(
                                        num_samples=num_samples,
                                        intv_args=intv_args
    )
    mixture_samples.append(Xobs)
    intv_args["true_params"]=obs_true_params
    intv_args_dict["obs"]=intv_args



    #Consolidating all the samples into one big pile
    mixture_samples = np.concatenate(mixture_samples,axis=0)




    #Now we are ready run the mini disentanglement algos
    gm = GaussianMixture(n_components=len(intv_args_dict),random_state=0).fit(
                                                mixture_samples
    )

    print("==================================")
    print("Estimated Means (unmatched):")
    pprint(gm.means_*(gm.means_>1e-5))
    print("==================================")
    pprint("Estimated Covarainces (unmatched):")
    pprint(gm.covariances_*(gm.covariances_>1e-5))
    min_err,min_perm = get_best_estimated_matching_error(intv_args_dict,gm)
    return min_err,min_perm

# %%
args={}
num_nodes=2
args["noise_mean_list"]=[0.0,0.0]
args["noise_sigma_list"]=[1.0,1.0]
args["adj_mat"]=np.array([
                [0,0],
                [1,0]
])
#Creating the SCM 
gSCM = GaussianSCM(args)

new_noise_mean_list=np.linspace(0,1,10)
sample_list=[100,200,400,800,1600,3200,6400]
mean_error_dict={}
for new_noise_mean in new_noise_mean_list:
    error_list = []
    for samples in sample_list:
        print("\n\n#####################################")
        print("Running EXPT with sample size:",samples)
        print("#####################################")
        err,_ = sample_expt_runner(gSCM,samples,num_nodes)
        error_list.append(err)
    mean_error_dict[str(new_noise_mean)]=error_list

    #Plotting the error
    plt.plot(sample_list,error_list,"-o",label="{:0.2f}".format(new_noise_mean))
plt.xlabel("Samples")
plt.ylabel("|$\Delta$Mean| + |$\Delta$Variance|")
plt.grid()
plt.legend()
# Out:
# ==================================
# Generating SCM
#
#
# #####################################
# Running EXPT with sample size: 100
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[0.11796585, 0.0439616 ],
#        [1.00000243, 1.07690726],
#        [0.00298141, 1.99999918]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.27117964,  1.20225795],
#         [ 1.20225795,  2.14587295]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  1.00526226]],
#
#        [[ 0.90333774, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 1.1653178749188555
# min_perm: ('obs', '0', '1')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  1.99999984],
#        [ 0.08711581,  0.10072994],
#        [ 1.00000467,  0.94370753]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.87821083, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.04157952,  0.98307326],
#         [ 0.98307326,  1.93193254]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  0.92410584]]])
# error: 0.690183486453559
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.        ,  1.04264041],
#        [ 0.03920336,  2.00000313],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  0.88467794]],
#
#        [[ 1.03104665,  0.        ],
#         [ 0.        ,  0.        ]],
#
#        [[ 0.81651769,  0.84682459],
#         [ 0.84682459,  1.84915524]]])
# error: 0.9320283927203007
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.05436363,  0.01880962],
#        [ 0.99999689,  0.96344892],
#        [-0.        ,  2.00000013]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.89876513,  0.89925158],
#         [ 0.89925158,  1.89061392]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  1.00012238]],
#
#        [[ 1.00940519,  0.        ],
#         [ 0.        ,  0.        ]]])
# error: 0.5469149380927782
# min_perm: ('obs', '0', '1')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 7.08315182e-04,  1.99999864e+00],
#        [ 1.00000369e+00,  9.83413789e-01],
#        [ 1.18414863e-02, -0.00000000e+00]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.03211788, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  0.94498762]],
#
#        [[ 0.99718118,  0.98427271],
#         [ 0.98427271,  2.00550555]]])
# error: 0.16926520856901422
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[1.57321220e-05, 1.99999964e+00],
#        [4.08256560e-04, 6.75072039e-04],
#        [9.99999184e-01, 1.02940791e+00]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.97546334, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.05314118,  1.09090711],
#         [ 1.09090711,  2.08634181]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.03297646]]])
# error: 0.40932730318411653
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 6400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.00000000e+00,  2.00000049e+00],
#        [-0.00000000e+00,  2.82478505e-05],
#        [ 9.99999589e-01,  9.89462274e-01]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[1.01615887, 0.        ],
#         [0.        , 0.        ]],
#
#        [[1.03787163, 1.04363855],
#         [1.04363855, 2.06862409]],
#
#        [[0.        , 0.        ],
#         [0.        , 1.01427469]]])
# error: 0.26690013006293156
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 100
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.16516358,  0.16648946],
#        [-0.        ,  2.        ],
#        [ 1.00005966,  0.99831255]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.11597249e+00,  1.03667139e+00],
#         [ 1.03667139e+00,  2.12139368e+00]],
#
#        [[ 9.11874874e-01, -0.00000000e+00],
#         [-0.00000000e+00,  0.00000000e+00]],
#
#        [[ 0.00000000e+00,  1.57444198e-05],
#         [ 1.57444198e-05,  9.17391537e-01]]])
# error: 0.8722975699328012
# min_perm: ('obs', '1', '0')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  2.        ],
#        [-0.        , -0.        ],
#        [ 0.99998586,  0.99499577]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.886411  , -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.06757345,  1.12002238],
#         [ 1.12002238,  2.08475608]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  0.90311307]]])
# error: 0.8828643716289892
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[0.99999546, 1.09939856],
#        [0.03903577, 2.        ],
#        [0.0031692 , 0.06431377]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  1.00523548]],
#
#        [[ 0.95851552, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.9981391 ,  0.99734286],
#         [ 0.99734286,  2.06343733]]])
# error: 0.32325967307587256
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.00000011,  0.93925124],
#        [-0.        ,  1.99999835],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        ,  0.        ],
#         [ 0.        ,  0.97755806]],
#
#        [[ 1.08572348, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.08089053,  1.10279281],
#         [ 1.10279281,  2.1044335 ]]])
# error: 0.6420640698694711
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  1.99999852],
#        [ 0.01105876,  0.03136549],
#        [ 0.99999778,  1.00916574]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.92791656, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.00405004,  1.00309054],
#         [ 1.00309054,  1.98569795]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  0.99261732]]])
# error: 0.20171185269745595
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.02498523,  1.99999919],
#        [ 0.99999997,  0.98547499],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.97444978, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.00102106]],
#
#        [[ 0.99065946,  0.96970195],
#         [ 0.96970195,  1.91303952]]])
# error: 0.261985482085853
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 6400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        , -0.        ],
#        [-0.        ,  1.99999937],
#        [ 0.99999985,  1.01422671]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.02420325,  1.04371043],
#         [ 1.04371043,  2.05508308]],
#
#        [[ 0.99722233, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.02025903]]])
# error: 0.2164769540151851
# min_perm: ('obs', '1', '0')
#
#
# #####################################
# Running EXPT with sample size: 100
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  2.        ],
#        [ 1.        ,  0.86275353],
#        [-0.        ,  0.10792134]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.7687799 , -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  0.96253259]],
#
#        [[ 1.23463618,  1.27348552],
#         [ 1.27348552,  2.20505263]]])
# error: 1.567133261495854
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.00499977,  1.99999999],
#        [-0.        , -0.        ],
#        [ 0.99998594,  0.92001288]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.00225319e+00, -0.00000000e+00],
#         [-0.00000000e+00,  0.00000000e+00]],
#
#        [[ 1.04532058e+00,  1.11557037e+00],
#         [ 1.11557037e+00,  2.18994901e+00]],
#
#        [[ 0.00000000e+00,  1.29946385e-05],
#         [ 1.29946385e-05,  9.70553524e-01]]])
# error: 0.6544662389141752
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.99999999,  1.01312074],
#        [ 0.01564392,  1.99999408],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  0.9012929 ]],
#
#        [[ 1.06272931, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.97938904,  1.01295671],
#         [ 1.01295671,  2.002432  ]]])
# error: 0.3246756227659503
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        , -0.        ],
#        [ 1.00000059,  1.04587247],
#        [-0.        ,  1.99999793]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.91967691,  0.94065638],
#         [ 0.94065638,  1.96615154]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.00898474]],
#
#        [[ 1.10263392, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 0.45631324265761003
# min_perm: ('obs', '0', '1')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.99999868,  1.01374554],
#        [-0.        , -0.        ],
#        [ 0.02337197,  1.99999865]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  1.01369257]],
#
#        [[ 1.03594677,  1.01281944],
#         [ 1.01281944,  2.02745395]],
#
#        [[ 1.02295219, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 0.23254906953909163
# min_perm: ('0', 'obs', '1')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  1.99999976],
#        [ 0.99999885,  1.00790068],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.96666101, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.02494898]],
#
#        [[ 1.02719876,  1.0207181 ],
#         [ 1.0207181 ,  1.97175601]]])
# error: 0.20949503523602925
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 6400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.9999993 ,  1.01038543],
#        [-0.        , -0.        ],
#        [ 0.00652949,  1.99999932]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  1.04167374]],
#
#        [[ 0.98777218,  0.98030575],
#         [ 0.98030575,  1.96828468]],
#
#        [[ 1.01037665, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 0.1959845309495632
# min_perm: ('0', 'obs', '1')
#
#
# #####################################
# Running EXPT with sample size: 100
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[1.        , 0.8362481 ],
#        [0.05786018, 2.        ],
#        [0.12316286, 0.20203065]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[0.        , 0.        ],
#         [0.        , 0.67969663]],
#
#        [[1.09966302, 0.        ],
#         [0.        , 0.        ]],
#
#        [[0.70323295, 0.78903131],
#         [0.78903131, 1.68843751]]])
# error: 1.9970409008523955
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.00223115,  2.        ],
#        [-0.        , -0.        ],
#        [ 1.00000018,  1.07550929]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[0.93327122, 0.        ],
#         [0.        , 0.        ]],
#
#        [[0.90569848, 0.92083997],
#         [0.92083997, 1.9966361 ]],
#
#        [[0.        , 0.        ],
#         [0.        , 0.98962908]]])
# error: 0.5026240356567553
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.00000108,  0.99031688],
#        [-0.        ,  2.        ],
#        [ 0.0751992 ,  0.0750293 ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[0.        , 0.        ],
#         [0.        , 0.89423734]],
#
#        [[1.05852286, 0.        ],
#         [0.        , 0.        ]],
#
#        [[0.9314331 , 0.84459682],
#         [0.84459682, 1.78382877]]])
# error: 0.9939046215722672
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  0.02609728],
#        [-0.        ,  2.        ],
#        [ 0.99999967,  0.95375461]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.00462027,  1.01018212],
#         [ 1.01018212,  2.00671189]],
#
#        [[ 0.86047014,  0.        ],
#         [ 0.        ,  0.        ]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  1.03279162]]])
# error: 0.3075358350716719
# min_perm: ('obs', '1', '0')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  1.99999911],
#        [ 0.02342729,  0.03951415],
#        [ 0.99999884,  0.99046395]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.00927228, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.01793002,  1.03132254],
#         [ 1.03132254,  2.02937968]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  1.02554333]]])
# error: 0.2172888587671214
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[0.01896549, 1.99999994],
#        [0.03149143, 0.03886952],
#        [1.00000114, 1.02383663]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.99297499, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.01008958,  1.01237068],
#         [ 1.01237068,  1.98386263]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.03487502]]])
# error: 0.20603891569581373
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 6400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.99999927,  0.9815502 ],
#        [ 0.00886418,  1.99999971],
#        [-0.        ,  0.01124057]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        ,  0.        ],
#         [ 0.        ,  0.98762522]],
#
#        [[ 1.00818679, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.97459721,  0.98713647],
#         [ 0.98713647,  1.98784159]]])
# error: 0.12411554343038524
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 100
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.        ,  0.82304347],
#        [ 0.02611602,  2.        ],
#        [ 0.03814279, -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[0.        , 0.        ],
#         [0.        , 0.76694064]],
#
#        [[0.96490346, 0.        ],
#         [0.        , 0.        ]],
#
#        [[1.07392677, 1.13755459],
#         [1.13755459, 2.13427947]]])
# error: 1.1410149519480868
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.1131542 ,  2.        ],
#        [-0.        , -0.        ],
#        [ 1.00000989,  1.15116266]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[8.54461810e-01, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00]],
#
#        [[1.03473517e+00, 9.26533683e-01],
#         [9.26533683e-01, 2.15941513e+00]],
#
#        [[0.00000000e+00, 1.13193200e-05],
#         [1.13193200e-05, 8.23881977e-01]]])
# error: 1.1014121902689276
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.        ,  1.0103408 ],
#        [ 0.00283147,  2.00000377],
#        [-0.        ,  0.03615267]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        ,  0.        ],
#         [ 0.        ,  0.93844284]],
#
#        [[ 0.88108246, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.11528071,  1.18009579],
#         [ 1.18009579,  2.1987392 ]]])
# error: 0.9045195970954352
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.0168118 , -0.        ],
#        [ 0.99999947,  1.06106323],
#        [-0.        ,  1.99999987]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.04613262,  1.07345527],
#         [ 1.07345527,  2.05962302]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  0.99565358]],
#
#        [[ 0.92466892, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 0.4426459548746293
# min_perm: ('obs', '0', '1')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  1.99999984],
#        [ 0.01035613,  0.05099839],
#        [ 0.999999  ,  0.99948482]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.94434185, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.96544416,  0.95050555],
#         [ 0.95050555,  1.93945526]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  1.02490175]]])
# error: 0.3500613414096152
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.04002461,  2.00000157],
#        [ 0.99999588,  0.99383234],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.05516391,  0.        ],
#         [ 0.        ,  0.        ]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  1.00637648]],
#
#        [[ 0.99415977,  0.9806621 ],
#         [ 0.9806621 ,  1.96453735]]])
# error: 0.2966020900027317
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 6400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 9.99999354e-01,  9.92634582e-01],
#        [-0.00000000e+00,  1.99999928e+00],
#        [-0.00000000e+00,  9.43050363e-04]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  0.97788563]],
#
#        [[ 0.97916859, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.00802381,  1.00249247],
#         [ 1.00249247,  1.98867641]]])
# error: 0.08016352040859544
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 100
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        , -0.        ],
#        [ 1.        ,  1.11814486],
#        [-0.        ,  1.99997049]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.87944196,  0.87607534],
#         [ 0.87607534,  1.79075148]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.0224632 ]],
#
#        [[ 1.10876426, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 0.9902144602310509
# min_perm: ('obs', '0', '1')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.01779307,  2.00001597],
#        [-0.        , -0.        ],
#        [ 1.00000135,  1.12171682]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[0.87542973, 0.        ],
#         [0.        , 0.        ]],
#
#        [[1.06913389, 1.11470374],
#         [1.11470374, 2.03004707]],
#
#        [[0.        , 0.        ],
#         [0.        , 0.89114364]]])
# error: 0.8171794765672327
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  2.00000166],
#        [-0.        , -0.        ],
#        [ 0.99999926,  0.91946053]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[1.10291788, 0.        ],
#         [0.        , 0.        ]],
#
#        [[0.89890581, 0.89826615],
#         [0.89826615, 1.87670774]],
#
#        [[0.        , 0.        ],
#         [0.        , 1.05662752]]])
# error: 0.8018710584301857
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.07790075,  0.12170128],
#        [ 0.99999357,  1.08426337],
#        [-0.        ,  1.99999877]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.01824553,  0.98042565],
#         [ 0.98042565,  1.91829052]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  0.92569549]],
#
#        [[ 1.02022898, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 0.5180231744777621
# min_perm: ('obs', '0', '1')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  2.00000172],
#        [-0.        , -0.        ],
#        [ 0.99999923,  1.0111134 ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.99816714,  0.        ],
#         [ 0.        ,  0.        ]],
#
#        [[ 1.00089439,  0.95805906],
#         [ 0.95805906,  1.95583542]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  0.97266535]]])
# error: 0.20390756136709715
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  2.00000083],
#        [ 0.01211773, -0.        ],
#        [ 1.00000033,  1.01838629]])
# ==================================
# ...
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.        ,  0.94969401],
#        [-0.        ,  2.        ],
#        [ 0.02187647, -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        ,  0.        ],
#         [ 0.        ,  0.94253883]],
#
#        [[ 0.94755691, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.78544527,  0.8973214 ],
#         [ 0.8973214 ,  1.75258489]]])
# error: 1.0369660694436897
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  2.        ],
#        [ 1.00000878,  0.92920283],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[1.03081703, 0.        ],
#         [0.        , 0.        ]],
#
#        [[0.        , 0.        ],
#         [0.        , 0.89260351]],
#
#        [[0.82889722, 0.87922033],
#         [0.87922033, 1.90268322]]])
# error: 0.8223207493043555
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.99999818,  0.97927847],
#        [-0.        ,  2.00000018],
#        [ 0.10949439,  0.08331201]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[0.        , 0.        ],
#         [0.        , 0.97132629]],
#
#        [[1.0528155 , 0.        ],
#         [0.        , 0.        ]],
#
#        [[0.93279029, 0.9146179 ],
#         [0.9146179 , 1.82194999]]])
# error: 0.780514555918062
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  1.99999851],
#        [ 0.99999932,  0.99342043],
#        [ 0.0035551 ,  0.01551402]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.0087302 , -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  0.97106315]],
#
#        [[ 0.96229158,  0.88530657],
#         [ 0.88530657,  1.84235096]]])
# error: 0.4972949038053178
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.0000002 ,  1.02612725],
#        [-0.        , -0.        ],
#        [-0.        ,  1.99999842]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        ,  0.        ],
#         [ 0.        ,  1.02263718]],
#
#        [[ 1.00236307,  0.98224734],
#         [ 0.98224734,  1.89111957]],
#
#        [[ 1.04700104, -0.        ],
#         [-0.        ,  0.        ]]])
# error: 0.392118939544759
# min_perm: ('0', 'obs', '1')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[-0.        ,  1.99999992],
#        [ 0.99999836,  0.99363535],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.04513096, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        , -0.        ],
#         [-0.        ,  0.97990557]],
#
#        [[ 0.96647163,  0.99029766],
#         [ 0.99029766,  2.02190658]]])
# error: 0.21799339355999162
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 6400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.99999941,  1.00344433],
#        [-0.        ,  2.00000127],
#        [-0.        , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  0.98652312]],
#
#        [[ 0.98424434,  0.        ],
#         [ 0.        ,  0.        ]],
#
#        [[ 0.96514044,  0.98631475],
#         [ 0.98631475,  1.98577939]]])
# error: 0.1398486994487471
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 100
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[1.        , 0.96082556],
#        [0.01197009, 2.        ],
#        [0.07513784, 0.03414489]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  1.10840249]],
#
#        [[ 0.90793271, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.28525346,  1.3008861 ],
#         [ 1.3008861 ,  2.30399832]]])
# error: 1.5519230309216905
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[0.0578727 , 1.99999299],
#        [1.        , 1.0877037 ],
#        [0.01087161, 0.02598372]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 1.04236452, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  1.13894758]],
#
#        [[ 1.13807188,  0.96189442],
#         [ 0.96189442,  1.7667441 ]]])
# error: 0.8112994108571283
# min_perm: ('1', '0', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.        ,  0.99806552],
#        [-0.        ,  1.9999991 ],
#        [ 0.0374719 , -0.        ]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        ,  0.        ],
#         [ 0.        ,  0.98735409]],
#
#        [[ 0.98107753, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.02520631,  1.01501421],
#         [ 1.01501421,  1.98771419]]])
# error: 0.17501675345298692
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 800
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.00000186,  1.06209346],
#        [-0.        ,  1.99999954],
#        [-0.        ,  0.00295452]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        ,  0.        ],
#         [ 0.        ,  1.0141741 ]],
#
#        [[ 0.98669136, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.02965204,  0.976991  ],
#         [ 0.976991  ,  1.89627395]]])
# error: 0.34185796780557554
# min_perm: ('0', '1', 'obs')
#
#
# #####################################
# Running EXPT with sample size: 1600
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.01300698,  2.00000048],
#        [ 0.00276745, -0.        ],
#        [ 1.00000243,  0.98852577]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.96735647, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.0407552 ,  1.10318319],
#         [ 1.10318319,  2.16248156]],
#
#        [[ 0.        ,  0.        ],
#         [ 0.        ,  0.96196521]]])
# error: 0.5166722755433711
# min_perm: ('1', 'obs', '0')
#
#
# #####################################
# Running EXPT with sample size: 3200
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 1.00000257,  1.01174661],
#        [-0.        , -0.        ],
#        [-0.        ,  2.00000071]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  0.96562284]],
#
#        [[ 1.01100173,  1.01281213],
#         [ 1.01281213,  1.97923851]],
#
#        [[ 0.98218326,  0.        ],
#         [ 0.        ,  0.        ]]])
# error: 0.18415841507371655
# min_perm: ('0', 'obs', '1')
#
#
# #####################################
# Running EXPT with sample size: 6400
# #####################################
# ==================================
# 'Generating samples for:'
# {'inode': 0, 'intv_type': 'do', 'new_mui': 1}
# 'True params:'
# {'Si': array([[0., 0.],
#        [0., 1.]]), 'mui': array([1., 1.])}
# ==================================
# 'Generating samples for:'
# {'inode': 1, 'intv_type': 'do', 'new_mui': 2}
# 'True params:'
# {'Si': array([[1., 0.],
#        [0., 0.]]), 'mui': array([0., 2.])}
# ==================================
# 'Generating samples for:'
# {'intv_type': 'obs'}
# 'True params:'
# {'Si': array([[1., 1.],
#        [1., 2.]]), 'mui': array([0., 0.])}
# ==================================
# Estimated Means (unmatched):
# array([[ 0.99999975,  1.00153827],
#        [-0.        ,  1.99999976],
#        [ 0.0035889 ,  0.01627307]])
# ==================================
# 'Estimated Covarainces (unmatched):'
# array([[[ 0.        , -0.        ],
#         [-0.        ,  0.99367664]],
#
#        [[ 0.99591417, -0.        ],
#         [-0.        ,  0.        ]],
#
#        [[ 1.01123526,  1.01107677],
#         [ 1.01107677,  2.00077716]]])
# error: 0.07528556552081236
# min_perm: ('0', '1', 'obs')
